# %%
#convert km to miles
kilometers=float(input("enetr distance in km"))
miles=km*0.62137
print("distance in miles= ",miles)
# Out:
# enetr distance in km12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #convert km to miles
#       2 kilometers=float(input("enetr distance in km"))
# ----> 3 miles=km*0.62137
#       4 print("distance in miles= ",miles)
#
# NameError: name 'km' is not defined

# %%
#convert km to miles
km=float(input("enetr distance in km"))
miles=km*0.62137
print("distance in miles= ",miles)
# Out:
# enetr distance in km12
# distance in miles=  7.45644

# %%
#convert km to miles
km=float(input("enetr distance in km: "))
miles=km*0.62137
print("distance in miles= " ,
      round(miles,2))
# Out:
# enetr distance in km: 10
# distance in miles=  6.21
