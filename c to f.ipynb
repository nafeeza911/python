# %%
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
# Out:
# enter the temperature in celcius: sss
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c=float(input("enter the temperature in celcius: "))
#       2 f=c*9/5+32
#
# ValueError: could not convert string to float: 'sss'

# %%
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32

# %%
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f)

# %%
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f

# %%
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f)
# Out:
# enter the temperature in celcius: 32
# temperature in fahrenhiet =  89.6

# %%
#convert celcius to fahrenhiet
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f)
# Out:
# enter the temperature in celcius: 23
# temperature in fahrenhiet =  73.4
