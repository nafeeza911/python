# %%
#convert celcius to fahrenhiet
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f)
# Out:
# enter the temperature in celcius: 100
# temperature in fahrenhiet =  212.0

# %%
#convert km to miles
km=float(input("enetr distance in km: "))
miles=km*0.62137
print("distance in miles= " ,
      round(miles,2))
# Out:
# enetr distance in km: 120
# distance in miles=  74.56
